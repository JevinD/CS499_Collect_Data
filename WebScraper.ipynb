# %%
import json
import csv
import tweepy
import re

#Twitter API credentials
#INSERT TWITTER CREDENTIALS HERE
consumer_key = ''
consumer_secret = ''
access_key = ''
access_secret = ''


def get_all_tweets(screen_name):
	#Twitter only allows access to a users most recent 3240 tweets with this method
	
	#authorize twitter, initialize tweepy
	auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
	auth.set_access_token(access_key, access_secret)
	api = tweepy.API(auth)
	
	#initialize a list to hold all the tweepy Tweets
	alltweets = []	
	
	#make initial request for most recent tweets (200 is the maximum allowed count)
	new_tweets = api.user_timeline(screen_name = screen_name,count=200)
	
	#save most recent tweets
	alltweets.extend(new_tweets)
	
	#save the id of the oldest tweet less one
	oldest = alltweets[-1].id - 1
	
	#keep grabbing tweets until there are no tweets left to grab
	while len(new_tweets) > 0:
		print ("getting tweets before %s ",  oldest)
		
		#all subsiquent requests use the max_id param to prevent duplicates
		new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
		
		#save most recent tweets
		alltweets.extend(new_tweets)
		
		#update the id of the oldest tweet less one
		oldest = alltweets[-1].id - 1
		
		print ("...%s tweets downloaded so far", len(alltweets))
	
	#transform the tweepy tweets into a 2D array that will populate the csv	
	outtweets = [[tweet.id_str, tweet.created_at,tweet.favorite_count, tweet.retweet_count,tweet.text] for tweet in alltweets]
	
	#write the csv	
	with open('%s_tweets.csv' %screen_name,'w',encoding = 'utf8') as f:
		writer = csv.writer(f)
		writer.writerow(["id","created_at","number of likes","number of retweets","text"])
		writer.writerows(outtweets)
	
	pass


if __name__ == '__main__':
    #pass in the username of the account you want to download
    username = input('Enter a Username ')
    get_all_tweets(username)
# Out:
# Enter a UsernameWendys
# getting tweets before %s  1120920790088736769
# ...%s tweets downloaded so far 400
# getting tweets before %s  1119303652991279103
# ...%s tweets downloaded so far 600
# getting tweets before %s  1118231181621854211
# ...%s tweets downloaded so far 800
# getting tweets before %s  1117182446112522239
# ...%s tweets downloaded so far 1000
# getting tweets before %s  1116369181912502271
# ...%s tweets downloaded so far 1200
# getting tweets before %s  1115659364319281151
# ...%s tweets downloaded so far 1400
# getting tweets before %s  1114638645200338946
# ...%s tweets downloaded so far 1600
# getting tweets before %s  1113861406821109759
# ...%s tweets downloaded so far 1800
# getting tweets before %s  1112945732754046976
# ...%s tweets downloaded so far 2000
# getting tweets before %s  1111694590610980866
# ...%s tweets downloaded so far 2200
# getting tweets before %s  1110662330797445120
# ...%s tweets downloaded so far 2400
# ...
